# %%
# %matplotlib inline
from sklearn.ensemble import RandomForestClassifier
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from time import time
con = 'mysql+pymysql://root@localhost/fx'
currency = "brl"
sql = "select * from rates where currency = ?"

# %%
df = pd.read_sql(sql,con,params={'currency':'brl'},index_col='Date',parse_dates=['Date'])
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /Users/skilbjo/.virtualenvs/data/lib/python3.5/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1138                         parameters,
# -> 1139                         context)
#    1140         except Exception as e:
#
# /Users/skilbjo/.virtualenvs/data/lib/python3.5/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     449     def do_execute(self, cursor, statement, parameters, context=None):
# --> 450         cursor.execute(statement, parameters)
#     451
#
# /Users/skilbjo/.virtualenvs/data/lib/python3.5/site-packages/pymysql/cursors.py in execute(self, query, args)
#     145
# --> 146         result = self._query(query)
#     147         self._executed = query
#
# ...
